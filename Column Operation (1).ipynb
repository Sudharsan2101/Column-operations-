# %%
import pandas as pd

# %%
mat=pd.read_csv("D:/market_fact.csv")

# %%
mat
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
mat['Orginal cost']=mat['Sales']+mat['Discount']

# %%
mat
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
mat['Average product']=mat['Sales']/mat['Order_Quantity']

# %%
mat
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
mat.rename(columns={'Sales':'Sales_amount'})
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id  Sales_amount  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818      136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818       42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818     4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818     2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818     4233.1500      0.08
# ...        ...      ...       ...        ...           ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798     2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798      127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798      243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798     3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798      603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
mat.rename(columns={'Prod_id':'Product_id','Ship_id':'Shipping_id'})
# Out:
#         Ord_id Product_id Shipping_id    Cust_id      Sales  Discount  \
# 0     Ord_5446    Prod_16    SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406    Prod_13    SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446     Prod_4    SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456     Prod_6    SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485    Prod_17    SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...        ...         ...        ...        ...       ...
# 8394  Ord_5353     Prod_4    SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411     Prod_6    SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388     Prod_6    SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348    Prod_15    SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459     Prod_6    SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# ...

# %%
mat.drop(['Average product'],axis=1)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
mat.drop(['Discount','Order_Quantity'],axis=1)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales   Profit  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100   -30.51
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700     4.56
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900  1148.90
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900   729.34
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500  1219.87
# ...        ...      ...       ...        ...        ...      ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395   374.63
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600   -74.03
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500   -70.85
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700   565.34
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900   131.39
#
#       Shipping_Cost  Product_Base_Margin  Orginal cost  Average product
# 0              3.60                 0.56      136.8200         5.948261
# ...

# %%
mat.columns=[col.upper()for col in mat.columns]

# %%
mat
# Out:
#         ORD_ID  PROD_ID   SHIP_ID    CUST_ID      SALES  DISCOUNT  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       ORDER_QUANTITY   PROFIT  SHIPPING_COST  PRODUCT_BASE_MARGIN  \
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
mat.columns=[col.lower()for col in mat.columns]

# %%
mat
# Out:
#         ord_id  prod_id   ship_id    cust_id      sales  discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       order_quantity   profit  shipping_cost  product_base_margin  \
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
mat.sort_values(by='cust_id',ascending=True )
# Out:
#         ord_id  prod_id   ship_id   cust_id     sales  discount  \
# 5858     Ord_1   Prod_1     SHP_1    Cust_1   261.540      0.04
# 1770    Ord_10   Prod_3    SHP_13   Cust_10    80.610      0.02
# 1507   Ord_271   Prod_5   SHP_369  Cust_100  2522.210      0.00
# 1506   Ord_271  Prod_17   SHP_370  Cust_100  4181.820      0.01
# 1505   Ord_227   Prod_7   SHP_315  Cust_100   181.780      0.02
# ...        ...      ...       ...       ...       ...       ...
# 7053  Ord_2612   Prod_6  SHP_3574  Cust_999   193.160      0.03
# 7054  Ord_2588   Prod_2  SHP_3543  Cust_999   508.730      0.08
# 7055  Ord_2685   Prod_4  SHP_3676  Cust_999   617.219      0.03
# 7048  Ord_2827   Prod_6  SHP_3889  Cust_999   614.910      0.02
# 7040  Ord_2668   Prod_2  SHP_3654  Cust_999    78.790      0.03
#
#       order_quantity   profit  shipping_cost  product_base_margin  \
# 5858               6  -213.25          35.00                 0.80
# ...

# %%
mat.sort_values(by=['order_quantity','cust_id'],ascending=[True,False])
# Out:
#         ord_id  prod_id   ship_id    cust_id      sales  discount  \
# 7045  Ord_2637  Prod_15  SHP_3607   Cust_999   379.8000      0.02
# 4087  Ord_2679  Prod_13  SHP_3668   Cust_996    13.0400      0.06
# 4526  Ord_2604   Prod_9  SHP_3565   Cust_993     8.3400      0.09
# 624   Ord_2681  Prod_13  SHP_3670   Cust_992     6.7500      0.08
# 8131  Ord_2619   Prod_8  SHP_3583   Cust_990    40.2900      0.00
# ...        ...      ...       ...        ...        ...       ...
# 7519  Ord_2676   Prod_8  SHP_3664  Cust_1029  3333.1000      0.10
# 4737  Ord_2777   Prod_6  SHP_3813  Cust_1024   375.1100      0.01
# 5367  Ord_2750   Prod_8  SHP_3774  Cust_1014   225.9400      0.09
# 4101  Ord_2769   Prod_4  SHP_3801  Cust_1007  1875.4145      0.05
# 3705  Ord_2591   Prod_6  SHP_3548  Cust_1000   346.0600      0.00
#
#       order_quantity  profit  shipping_cost  product_base_margin  \
# 7045               1 -183.09          58.95                 0.57
# ...

# %%
mat.drop(['cust_id','product_base_margin'],axis=1,inplace=True)

# %%
mat
# Out:
#         ord_id  prod_id   ship_id      sales   profit  shipping_cost  \
# 0     Ord_5446  Prod_16  SHP_7609   136.8100   -30.51           3.60
# 1     Ord_5406  Prod_13  SHP_7549    42.2700     4.56           0.93
# 2     Ord_5446   Prod_4  SHP_7610  4701.6900  1148.90           2.50
# 3     Ord_5456   Prod_6  SHP_7625  2337.8900   729.34          14.30
# 4     Ord_5485  Prod_17  SHP_7664  4233.1500  1219.87          26.30
# ...        ...      ...       ...        ...      ...            ...
# 8394  Ord_5353   Prod_4  SHP_7479  2841.4395   374.63           7.69
# 8395  Ord_5411   Prod_6  SHP_7555   127.1600   -74.03           6.92
# 8396  Ord_5388   Prod_6  SHP_7524   243.0500   -70.85           5.35
# 8397  Ord_5348  Prod_15  SHP_7469  3872.8700   565.34          30.00
# 8398  Ord_5459   Prod_6  SHP_7628   603.6900   131.39           4.86
#
#       orginal cost  average product
# 0         136.8200         5.948261
# 1          42.2800         3.251538
# ...

# %%
mat=pd.read_csv("D:/market_fact.csv")

# %%
mat
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
mat.groupby('Cust_id').count()
# Out:
#            Ord_id  Prod_id  Ship_id  Sales  Discount  Order_Quantity  Profit  \
# Cust_id
# Cust_1          1        1        1      1         1               1       1
# Cust_10         1        1        1      1         1               1       1
# Cust_100        6        6        6      6         6               6       6
# Cust_1000       7        7        7      7         7               7       7
# Cust_1001      10       10       10     10        10              10      10
# ...           ...      ...      ...    ...       ...             ...     ...
# Cust_995       12       12       12     12        12              12      12
# Cust_996        5        5        5      5         5               5       5
# Cust_997       10       10       10     10        10              10      10
# Cust_998        4        4        4      4         4               4       4
# Cust_999       20       20       20     20        20              20      20
#
# ...

# %%
print(mat['Ord_id'].isnull().sum())
# Out:
# 0

# %%
mat=pd.read_csv("D:/market_fact.csv")

# %%
print(mat['Ord_id'].isnull().sum())
# Out:
# 1

# %%
mat=pd.read_csv("D:/market_fact.csv")

# %%
print(mat['Ord_id'].isnull().sum())
# Out:
# 0

# %%
len(mat.columns.values)
# Out:
# 10

# %%
print(mat.columns.values)
# Out:
# ['Ord_id' 'Prod_id' 'Ship_id' 'Cust_id' 'Sales' 'Discount'
#  'Order_Quantity' 'Profit' 'Shipping_Cost' 'Product_Base_Margin']
